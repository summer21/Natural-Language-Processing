# %% [markdown]
# # Finding more informative words in text

# %% [markdown]
# we find find out most cooman words using most_comman() function and use to find out the least comman word using  function hapaxes().But they not provide the greater insight.so we use other method.

# %%
import nltk

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# [u'austen-emma.txt',
#  u'austen-persuasion.txt',
#  u'austen-sense.txt',
#  u'bible-kjv.txt',
#  u'blake-poems.txt',
#  u'bryant-stories.txt',
#  u'burgess-busterbrown.txt',
#  u'carroll-alice.txt',
#  u'chesterton-ball.txt',
#  u'chesterton-brown.txt',
#  u'chesterton-thursday.txt',
#  u'edgeworth-parents.txt',
#  u'melville-moby_dick.txt',
#  u'milton-paradise.txt',
#  u'shakespeare-caesar.txt',
#  u'shakespeare-hamlet.txt',
#  u'shakespeare-macbeth.txt',
#  u'whitman-leaves.txt']

# %%
alice = nltk.corpus.gutenberg.words("carroll-alice.txt")

# %%
alice
# Out:
# [u'[', u'Alice', u"'", u's', u'Adventures', u'in', ...]

# %%
alice_fd = nltk.FreqDist(alice)

# %%
alice_fd
# Out:
# FreqDist({u'secondly': 2,
#           u'pardon': 6,
#           u'hatters': 1,
#           u'saves': 1,
#           u'knelt': 1,
#           u'four': 8,
#           u'Does': 2,
#           u'sleep': 6,
#           u'hanging': 3,
#           u'ringlets': 2,
#           u'oldest': 1,
#           u'hate': 2,
#           u'assembled': 2,
#           u'forget': 2,
#           u'whose': 2,
#           u'swam': 5,
#           u'blacking': 1,
#           u'presents': 2,
#           u'under': 16,
#           u'inwards': 1,
#           u'sorry': 1,
#           u'worth': 4,
#           u'barley': 1,
#           u'Mystery': 2,
#           u'struck': 2,
#           u'rise': 1,
#           u'every': 12,
#           u'fireplace': 1,
#           u'school': 6,
#           u'prize': 1,
#           u'wooden': 1,
#           u'pinch': 1,
#           u'NEAR': 1,
#           u'Dinn': 1,
#           u'Go': 3,
#           u'favoured': 1,
#           u'leaders': 1,
#           u'tired': 7,
# ...

# %%
alice_fd.most_common(100)
# Out:
# [(u',', 1993),
#  (u"'", 1731),
#  (u'the', 1527),
#  (u'and', 802),
#  (u'.', 764),
#  (u'to', 725),
#  (u'a', 615),
#  (u'I', 543),
#  (u'it', 527),
#  (u'she', 509),
#  (u'of', 500),
#  (u'said', 456),
#  (u",'", 397),
#  (u'Alice', 396),
#  (u'in', 357),
#  (u'was', 352),
#  (u'you', 345),
#  (u"!'", 278),
#  (u'that', 275),
#  (u'as', 246),
#  (u'her', 243),
#  (u't', 216),
#  (u':', 216),
#  (u'at', 202),
#  (u's', 195),
#  (u'on', 189),
#  (u".'", 187),
#  (u';', 186),
#  (u'had', 177),
#  (u'with', 175),
#  (u'all', 173),
#  (u'!', 155),
#  (u"?'", 154),
#  (u'be', 145),
#  (u'-', 141),
#  (u'for', 140),
#  (u'--', 140),
#  (u'but', 133),
#  (u'they', 129),
#  (u'not', 129),
#  (u'very', 126),
#  (u'little', 125),
#  (u'so', 124),
#  (u'out', 116),
#  (u'this', 113),
#  (u'The', 108),
#  (u'he', 101),
#  (u'down', 99),
#  (u'up', 98),
#  (u'is', 97),
#  (u'one', 94),
#  (u'his', 94),
#  (u'about', 94),
#  (u'what', 93),
#  (u'them', 88),
#  (u'know', 87),
#  (u'were', 85),
# ...

# %%
alice_fd.hapaxes()
# Out:
# [u'Tut',
#  u'saves',
#  u'knelt',
#  u'oldest',
#  u'consider',
#  u'YOURS',
#  u'inwards',
#  u'sorry',
#  u'Nearly',
#  u'mournful',
#  u'rise',
#  u'fireplace',
#  u'prize',
#  u'wooden',
#  u'pinch',
#  u'NEAR',
#  u'favoured',
#  u'leaders',
#  u'feathers',
#  u'BEG',
#  u'BEE',
#  u'elegant',
#  u'louder',
#  u'CURTSEYING',
#  u'machines',
#  u'shining',
#  u'VOICE',
#  u'hide',
#  u'pace',
#  u'thunder',
#  u'weren',
#  u'Game',
#  u'conduct',
#  u'wrapping',
#  u'protection',
#  u'cardboard',
#  u'daughter',
#  u'Herald',
#  u'smoke',
#  u'grumbled',
#  u'explained',
#  u'patience',
#  u'drowned',
#  u'punching',
#  u'blacking',
#  u'insult',
#  u'overhead',
#  u'leant',
#  u'peeping',
#  u'Rule',
#  u'adjourn',
#  u'locked',
#  u'worm',
#  u'obstacle',
#  u'rosetree',
#  u'Visit',
#  u'flung',
#  u'returned',
#  u'Tillie',
#  u'complaining',
#  u'agony',
#  u'LL',
#  u'returning',
#  u'Jack',
#  u'III',
#  u'Zealand',
#  u'poker',
#  u'flustered',
#  u'lad',
#  u'ladder',
# ...

# %% [markdown]
# Now we find out the Descriptive  word and not discriptive words and seprates both them.

# %%
malvi = nltk.corpus.gutenberg.words("melville-moby_dick.txt")

# %%
malvi_fd = nltk.FreqDist(malvi)

# %%
malvi_fd
# Out:
# FreqDist({u'foul': 11,
#           u'four': 74,
#           u'fleeces': 1,
#           u'woods': 9,
#           u'clotted': 2,
#           u'hanging': 19,
#           u'woody': 1,
#           u'Until': 2,
#           u'disobeying': 1,
#           u'canes': 2,
#           u'Westers': 1,
#           u'DRYDEN': 1,
#           u'Untried': 1,
#           u'Western': 1,
#           u'meadows': 3,
#           u'sinking': 13,
#           u'oceans': 14,
#           u'tantalizing': 3,
#           u'leisurely': 2,
#           u'medicament': 1,
#           u'stabbed': 1,
#           u'bringing': 10,
#           u'wooded': 1,
#           u'uttering': 2,
#           u'Less': 2,
#           u'wooden': 26,
#           u'Saco': 1,
#           u'broiled': 3,
#           u'solid': 17,
#           u'persisted': 2,
#           u'Does': 6,
#           u'soladoes': 1,
#           u'crotch': 9,
#           u'Paul': 4,
#           u'ornamental': 1,
#           u'FIGURED': 1,
#           u'sooty': 3,
# ...

# %%
malvi_fd_100 = malvi_fd.most_common(100)

# %%
alice_fd_100 = alice_fd.most_common(100)

# %%
set(alice_fd_100) - set(malvi_fd_100)
# Out:
# {(u'!', 155),
#  (u"!'", 278),
#  (u"'", 1731),
#  (u'*', 60),
#  (u',', 1993),
#  (u",'", 397),
#  (u'-', 141),
#  (u'--', 140),
#  (u'.', 764),
#  (u".'", 187),
#  (u':', 216),
#  (u';', 186),
#  (u"?'", 154),
#  (u'Alice', 396),
#  (u'And', 67),
#  (u'Gryphon', 55),
#  (u'Hatter', 55),
#  (u'I', 543),
#  (u'It', 64),
#  (u'King', 61),
#  (u'Mock', 56),
#  (u'Queen', 74),
#  (u'The', 108),
#  (u'Turtle', 59),
#  (u'a', 615),
#  (u'about', 94),
#  (u'again', 83),
#  (u'all', 173),
#  (u'an', 52),
#  (u'and', 802),
#  (u'as', 246),
#  (u'at', 202),
#  (u'be', 145),
#  (u'began', 58),
#  (u'but', 133),
#  (u'by', 55),
#  (u'can', 57),
#  (u'could', 73),
#  (u'did', 60),
#  (u'do', 68),
#  (u'don', 51),
#  (u'down', 99),
#  (u'for', 140),
#  (u'had', 177),
#  (u'have', 73),
#  (u'he', 101),
#  (u'her', 243),
#  (u'herself', 83),
#  (u'his', 94),
#  (u'if', 78),
#  (u'in', 357),
#  (u'into', 67),
#  (u'is', 97),
#  (u'it', 527),
#  (u'its', 56),
#  (u'know', 87),
#  (u'like', 84),
# ...

# %%
set(malvi_fd_100)- set(alice_fd_100)
# Out:
# {(u'!', 1269),
#  (u'!"', 305),
#  (u'"', 1478),
#  (u"'", 2684),
#  (u',', 18713),
#  (u'-', 2552),
#  (u'--', 1070),
#  (u'.', 6862),
#  (u'."', 489),
#  (u';', 4072),
#  (u'?', 637),
#  (u'Ahab', 501),
#  (u'And', 369),
#  (u'But', 705),
#  (u'I', 2124),
#  (u'It', 310),
#  (u'The', 612),
#  (u'a', 4569),
#  (u'about', 304),
#  (u'all', 1462),
#  (u'an', 582),
#  (u'and', 6024),
#  (u'any', 320),
#  (u'are', 586),
#  (u'as', 1620),
#  (u'at', 1231),
#  (u'be', 1030),
#  (u'been', 415),
#  (u'boat', 330),
#  (u'but', 1113),
#  (u'by', 1137),
#  (u'down', 364),
#  (u'for', 1414),
#  (u'from', 1052),
#  (u'had', 767),
#  (u'have', 760),
#  (u'he', 1661),
#  (u'head', 335),
#  (u'her', 329),
#  (u'him', 1058),
#  (u'his', 2459),
#  (u'if', 421),
#  (u'in', 3916),
#  (u'into', 520),
#  (u'is', 1695),
#  (u'it', 2209),
#  (u'its', 372),
#  (u'like', 624),
#  (u'long', 318),
#  (u'man', 508),
#  (u'me', 627),
#  (u'more', 501),
#  (u'my', 564),
#  (u'no', 484),
#  (u'not', 1103),
# ...

# %%
we genrally used that case other place Like term frequency vs  inverce Document Frequeny.
